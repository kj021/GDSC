# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import requests
from bs4 import BeautifulSoup
import re
import lxml

# %%
# 크롤링할 사이트 주소를 정의한다
url = "https://health.kdca.go.kr/healthinfo/biz/health/gnrlzHealthInfo/gnrlzHealthInfo/gnrlzHealthInfoView.do"

# %%
data= {
    'lclasSn': '1',
    'cntnts_sn': '5963',
    'searchTy': 'A',
    'pageIndex':'1'
}

# %%
# 사이트의 HTML 구조에 기반하여 크롤링을 수행한다.
req = requests.post(url, data=data)
print(req.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta name="format-detection" content="telephone=no, address=no, email=no" />
#     <meta name="keywords" content="국가건강정보포털" />
#     <meta name="description" content="국가건강정보포털" />
#     <title>질병관리청 국가건강정보포털-뇌동맥류</title>
#     <meta name="viewport" content="width=device-width, user-scalable=no">
#     <!-- 공통 -->
#     <script type="text/javascript" src="/healthinfo/static/js/jquery-3.4.1.min.js"></script>
#     <script type="text/javascript" src="/healthinfo/static/abs/default/jquery/jquery.cookie.js"></script>
#     <script type="text/javascript" src="/healthinfo/static/js/common.js"></script>
#     <script type="text/javascript" src="/healthinfo/static/js/slick.min.js"></script>
#     <script type="text/javascript" src="/healthinfo/static/js/swiper.min.js"></script>
#
# ...

# %%
html = req.content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
contents_table = soup.find(name="table")

# %%
result = contents_table.find(name="body")
if result != None:
    result1 = result.find('body')
    print(result1)
else:
    print("result value가 None입니다")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 result = contents_table.find(name="body")
#       2 if result != None:
#       3     result1 = result.find('body')
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
table_rows = table_body.find_all(name="tr")

# a 태그의 href 속성을 리스트로 추출하여 크롤링할 페이지 리스트를 생성한다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        page_urls.append(page_url)
        
# 중복 url을 제거한다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
